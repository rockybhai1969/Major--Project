# %%
import pandas as pd
import numpy as ny

# %%
df=pd.read_csv('appstore_games.csv')

# %%
df.head()
# Out:
#                                                  URL         ID  \
# 0   https://apps.apple.com/us/app/sudoku/id284921427  284921427
# 1  https://apps.apple.com/us/app/reversi/id284926400  284926400
# 2  https://apps.apple.com/us/app/morocco/id284946595  284946595
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  285755462
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  285831220
#
#             Name Subtitle                                           Icon URL  \
# 0         Sudoku      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1        Reversi      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2        Morocco      NaN  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  Sudoku (Free)      NaN  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4   Senet Deluxe      NaN  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# ...

# %%
to_drop=['URL','ID','Icon URL','Subtitle','In-app Purchases','Description','Age Rating','Primary Genre']
df.drop(to_drop,inplace=True,axis=1)

# %%
df.head(100)
# Out:
#                               Name  Average User Rating  User Rating Count  \
# 0                           Sudoku                  4.0             3553.0
# 1                          Reversi                  3.5              284.0
# 2                          Morocco                  3.0             8376.0
# 3                    Sudoku (Free)                  3.5           190394.0
# 4                     Senet Deluxe                  3.5               28.0
# ..                             ...                  ...                ...
# 95                    Crystal Mine                  2.0              353.0
# 96                           Nerve                  2.5               47.0
# 97                         Pebbles                  3.0              866.0
# 98  AirTycoon - Airline Management                  3.5             3416.0
# 99               Jungle Crash Land                  3.5            67670.0
#
#     Price                 Developer  \
# ...

# %%
df["total rating"]=df["Average User Rating"]*df['User Rating Count']

# %%
df.head()
# Out:
#             Name  Average User Rating  User Rating Count  Price  \
# 0         Sudoku                  4.0             3553.0   2.99
# 1        Reversi                  3.5              284.0   1.99
# 2        Morocco                  3.0             8376.0   0.00
# 3  Sudoku (Free)                  3.5           190394.0   0.00
# 4   Senet Deluxe                  3.5               28.0   2.99
#
#                   Developer  \
# 0  Mighty Mighty Good Games
# 1          Kiss The Machine
# 2               Bayou Games
# 3  Mighty Mighty Good Games
# 4           RoGame Software
#
#                                            Languages        Size  \
# 0  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# 1                                                 EN  12328960.0
# 2                                                 EN    674816.0
# 3  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  21552128.0
# 4  DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...  34689024.0
#
# ...

# %%
df.groupby(['Name','Genres'])['total rating'].max()
# Out:
# Name                                                                 Genres
# ! Chess !                                                            Games, Entertainment, Strategy, Board       1179.0
# ! OH Fantastic Free Kick + Kick Wall Challenge                       Games, Strategy, Sports, Sports                NaN
# !Ball Shots - Premium                                                Games, Entertainment, Strategy, Action         NaN
# !Dice In Cup : Premium                                               Games, Strategy, Role Playing, Education       NaN
# !Dots and Boxes : Premium                                            Games, Strategy, Casual                        NaN
#                                                                                                                   ...
# ` Flea Pop Puzzle Games For Free Kids Mind Teaser Quiz               Games, Puzzle, Entertainment, Strategy        20.0
# ...

# %%
df[df['total rating']==df['total rating'].max()]
# Out:
#                 Name  Average User Rating  User Rating Count  Price  \
# 1378  Clash of Clans                  4.5          3032734.0    0.0
#
#       Developer                                          Languages  \
# 1378  Supercell  AR, NL, EN, FI, FR, DE, ID, IT, JA, KO, MS, NB...
#
#              Size                                  Genres  \
# 1378  161219584.0  Games, Action, Entertainment, Strategy
#
#      Original Release Date Current Version Release Date  total rating
# 1378             2/08/2012                   20/06/2019    13647303.0

# %%
import matplotlib.pyplot

# %%
ax=df.plot.bar(x='Average User Rating',y='Price',rot=0)

# %%
df['Price'].max()
# Out:
# 179.99

# %%
df['']
